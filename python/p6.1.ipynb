# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np
import pandas as pd

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# %%
i = np.arange(-1, 1, .01)
X, Y = np.meshgrid(i, i)
Z = X**2 - Y**2
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
fig

# %%
fig, ax = plt.subplots(3, figsize=(14, 10), subplot_kw={'projection':'3d'})

# %%
norm = mpl.colors.Normalize(-abs(Z).max(), abs(Z).max())
ax[0].plot_surface(X, Y, Z, rstride=1, cstride=1, linewidth=0, norm=norm)
ax[2].contour(X, Y, Z, zdir='z', offset=0, cmap=mpl.cm.Blues)

# %%
fig

# %% [markdown]
# x, y = np.meshgrid(a, b)
#
# y, x = np.mgrid\[a, b\], a, b - slices:
#
# a = 1:10:20j - from 1 to 10, 20 points

# %%
350-80*1.28
# Out:
# 247.6

# %%
20/.44
# Out:
# 45.45454545454545

# %%
n = np.random.normal(loc=0, scale=1, size=100_000)
r = np.random.random(size=100_000)
g = np.random.gamma(2, size=100_000)
df = pd.DataFrame({'normal':n, 'random':r, 'gamma':g})

# %%
# %matplotlib inline
plt.figure()

# %%
_ = plt.boxplot(df.normal, whis=[5.59, 100])

# %%
_ = plt.boxplot(df, whis=np.inf)
