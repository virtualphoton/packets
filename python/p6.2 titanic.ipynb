# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = pd.read_csv('titanic.csv')

# %%
t = a.isnull().sum(axis=0) != 0

# %%
# %matplotlib inline
males = a.Age.dropna().loc[(a.Sex=='male') & (a.Survived == 1)]
females = a.Age.dropna().loc[(a.Sex=='female') & (a.Survived == 1)]
_ = plt.boxplot([males, females], labels=['male', 'female'])

# %%
_ = plt.violinplot([males, females])

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
a.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
a.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
a.head(5)['Age']
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
a.head(5)[['Age', 'Sex']]
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
a['Relatives'] = a.SibSp + a.Parch
a['HasRelatives'] = a.Relatives != 0

# %%
a.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
a.sort_values('Fare', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %%
a.loc[440:450:2][['Name', 'Sex']]
# Out:
#                                             Name     Sex
# 440  Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female
# 442                    Petterson, Mr. Johan Emil    male
# 444            Johannesen-Bratthammer, Mr. Bernt    male
# 446            Mellinger, Miss. Madeleine Violet  female
# 448               Baclini, Miss. Marie Catherine  female
# 450                        West, Mr. Edwy Arthur    male

# %%
s = a[a.Embarked == 'S']

# %%
len(s)
# Out:
# 644

# %%
a[a.PassengerId.isin([564, 442])][['Name', 'Sex']]
# Out:
#                   Name   Sex
# 441    Hampe, Mr. Leon  male
# 563  Simmons, Mr. John  male

# %%
dead = a[a.Survived == 0]
survived = a[a.Survived == 1]
print(f'{len(dead)=}, {len(survived)=}')
print(f'males survived: {(survived.Sex=="male").sum()}, females survived: {(survived.Sex=="female").sum()}')
# Out:
# len(dead)=549, len(survived)=342
# males survived: 109, females survived: 233

# %%
a.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
a.Pclass = a.Pclass.replace({'1':'Elite', '2':'Middle class', '3':'Proletarian'})

# %%
a.head(20)
# Out:
#     PassengerId  Survived        Pclass  \
# 0             1         0   Proletarian
# 1             2         1         Elite
# 2             3         1   Proletarian
# 3             4         1         Elite
# 4             5         0   Proletarian
# 5             6         0   Proletarian
# 6             7         0         Elite
# 7             8         0   Proletarian
# 8             9         1   Proletarian
# 9            10         1  Middle class
# 10           11         1   Proletarian
# 11           12         1         Elite
# 12           13         0   Proletarian
# 13           14         0   Proletarian
# 14           15         0   Proletarian
# 15           16         1  Middle class
# 16           17         0   Proletarian
# 17           18         1  Middle class
# 18           19         0   Proletarian
# 19           20         1   Proletarian
#
#                                                  Name     Sex   Age  SibSp  \
# ...

# %%
a.Fare_bin = (a.Fare < 20).replace({True:'cheap', False:'expensive'})

# %%
b = a.dropna(subset=['Age', 'Sex'])
len(a), len(b)
# Out:
# (891, 714)

# %%
a_2 = a.dropna(thresh=len(a_2.loc[0]) - 1)
len(a_2)
# Out:
# 733

# %%
a_3 = a.fillna('Omission')

# %%
a_3
# Out:
#      PassengerId  Survived        Pclass  \
# 0              1         0   Proletarian
# 1              2         1         Elite
# 2              3         1   Proletarian
# 3              4         1         Elite
# 4              5         0   Proletarian
# ..           ...       ...           ...
# 886          887         0  Middle class
# 887          888         1         Elite
# 888          889         0   Proletarian
# 889          890         1         Elite
# 890          891         0   Proletarian
#
#                                                   Name     Sex       Age  \
# 0                              Braund, Mr. Owen Harris    male      22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      38.0
# 2                               Heikkinen, Miss. Laina  female      26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      35.0
# 4                             Allen, Mr. William Henry    male      35.0
# ...

# %%
mean = a.Age.mean()
a_4 = a.copy()
a_4.Age = a_4.Age.fillna(mean)

# %%
a_4
# Out:
#      PassengerId  Survived        Pclass  \
# 0              1         0   Proletarian
# 1              2         1         Elite
# 2              3         1   Proletarian
# 3              4         1         Elite
# 4              5         0   Proletarian
# ..           ...       ...           ...
# 886          887         0  Middle class
# 887          888         1         Elite
# 888          889         0   Proletarian
# 889          890         1         Elite
# 890          891         0   Proletarian
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
piv = pd.pivot_table(a, index=['Sex'], columns=['Survived'], values='Survived', aggfunc=len)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4808/161140834.py in <module>
# ----> 1 piv = pd.pivot_table(a, index=['Sex'], columns=['Survived'], values='Survived', aggfunc=len)
#
# ~\anaconda3\envs\manipulator\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
#      96         data,
#      97         values,
#
# ~\anaconda3\envs\manipulator\lib\site-packages\pandas\core\reshape\pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     162         values = list(values)
#     163
# ...

# %%
pd.pivot_table(a, index='Sex', columns='Survived', values='Fare', aggfunc=len)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109
